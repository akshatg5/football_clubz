# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# import plotly.express as px
# import plotly.graph_objects as go
import io

from database import load_all_from_interactions

# %%
df_main = load_all_from_interactions()

# %%
df_main
# Out:
#     id          full_name  age          club_name       best_manager  \
# 0    1     Akshat Girdhar   21    Manchester City      Pep Guardiola
# 1    2         Tony Stark   40        Real Madrid    Carlo Ancelotti
# 2    3       Aryan Mishra   22            Chelsea      Jose Mourinho
# 3    4  Kshaunish Girdhar   14          Barcelona      Pep Guardiola
# 4    5        Bruce Wayne   45  Manchester United  Sir Alex Ferguson
# 5    6       Steve Rogers  108          Barcelona      Pep Guardiola
# 6    7        Scott Lanng   35               Ajax       Johan Cruyff
# 7    8       Clint Barton   32        Real Madrid    Zinedine Zidane
# 8    9     Kavita Girdhar   49          Liverpool      Pep Guardiola
# 9   10          Nick Fury   50      Bayern Munich      Arsène Wenger
# 10  11       Pepper Potts   35          Liverpool      Jose Mourinho
# 11  12       Peter Parker   22          Barcelona      Pep Guardiola
#
#           best_player             best_cf             best_m  \
# 0        Lionel Messi   Cristiano Ronaldo    Kevin De Bruyne
# 1   Cristiano Ronaldo       Karim Benzema         Toni Kroos
# 2          Ronaldinho        Lionel Messi    Zinedine Zidane
# 3        Lionel Messi        Lionel Messi     Andrés Iniesta
# 4   Cristiano Ronaldo         Luis Suárez         Paul Pogba
# 5        Lionel Messi  Robert Lewandowski     Andrés Iniesta
# 6        Johan Cruyff      Erling Haaland  Franz Beckenbauer
# 7        Lionel Messi         Luis Suárez     Xavi Hernández
# 8        Lionel Messi   Gabriel Batistuta     Michel Platini
# 9                Pelé       Sergio Agüero         Toni Kroos
# 10  Cristiano Ronaldo       Thierry Henry    Zinedine Zidane
# 11     Diego Maradona       Kylian Mbappé         Paul Pogba
#
#              best_cb                best_gk
# 0       Sergio Ramos           Manuel Neuer
# 1       Sergio Ramos       Thibaut Courtois
# 2      Paolo Maldini           Manuel Neuer
# 3       Carles Puyol  Marc-André ter Stegen
# 4      Harry Maguire           David de Gea
# 5       Carles Puyol  Marc-André ter Stegen
# 6   Matthijs de Ligt       Thibaut Courtois
# 7       Sergio Ramos           Manuel Neuer
# 8         Joel Matip            Hugo Lloris
# 9       Sergio Ramos       Thibaut Courtois
# 10   Virgil van Dijk                Ederson
# 11   Virgil van Dijk       Thibaut Courtois

# %%
clubs = df_main['club_name'].value_counts()

# %%
clubs
# Out:
# club_name
# Barcelona            3
# Real Madrid          2
# Liverpool            2
# Manchester City      1
# Chelsea              1
# Manchester United    1
# Ajax                 1
# Bayern Munich        1
# Name: count, dtype: int64

# %%
type(clubs)
# Out:
# pandas.core.series.Series

# %%
labels = clubs.index.tolist()
values = clubs.values.tolist()

# %%
labels
# Out:
# ['Barcelona',
#  'Real Madrid',
#  'Liverpool',
#  'Manchester City',
#  'Chelsea',
#  'Manchester United',
#  'Ajax',
#  'Bayern Munich']

# %%
values
# Out:
# [3, 2, 2, 1, 1, 1, 1, 1]

# %%
def club_piechart():
    clubs = df_main['club_name'].value_counts()
    labels = clubs.index.tolist()
    values = clubs.values.tolist()
    fig,ax = plt.subplots(facecolor = 'none',figsize=(20,18))
    colors = sns.color_palette('pastel')
    ax.set_title("Club Distribution",fontsize=29)
    ax.pie(labels=labels,x=values,colors=colors,autopct= "%1.1f%%",textprops={'fontsize':25})
    ax.tick_params(axis="both",labelsize=100)
    club_piechart = plt.savefig('static/club_piechart.png')
    return club_piechart

# %%
club_piechart()
